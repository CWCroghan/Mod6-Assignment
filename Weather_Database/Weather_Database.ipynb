# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coor in coordinates:
    city = citipy.nearest_city(coor[0], coor[1]).city_name
    
    #Add to cities only if it is unique
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 731

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()

        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_max_temp = city_weather["main"]["temp_max"]

        city_descrpt = city_weather['weather'][0]['main']
        city_country = city_weather["sys"]["country"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Current Description":city_descrpt, 
            "Country": city_country,
            "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto penasco
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | muriae
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | buala
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | moron
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 1 | eureka
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | kuito
# Processing Record 17 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | codrington
# Processing Record 20 of Set 1 | half moon bay
# Processing Record 21 of Set 1 | konevo
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | bathsheba
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | torrox
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | ulladulla
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | prince rupert
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | namibe
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | okhotsk
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | pisco
# Processing Record 44 of Set 1 | foam lake
# Processing Record 45 of Set 1 | kikwit
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | aklavik
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | kursumlija
# Processing Record 5 of Set 2 | ottawa
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 2 | yakeshi
# Processing Record 9 of Set 2 | samarai
# Processing Record 10 of Set 2 | flinders
# Processing Record 11 of Set 2 | saint-francois
# Processing Record 12 of Set 2 | shimoda
# Processing Record 13 of Set 2 | lethem
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | dingli
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | umm bab
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | cayenne
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | westport
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | mbanza-ngungu
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | la ronge
# Processing Record 28 of Set 2 | palmer
# Processing Record 29 of Set 2 | klaksvik
# Processing Record 30 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | makakilo city
# Processing Record 33 of Set 2 | frunze
# Processing Record 34 of Set 2 | mulki
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | beloha
# Processing Record 38 of Set 2 | birao
# Processing Record 39 of Set 2 | pemangkat
# Processing Record 40 of Set 2 | lamar
# Processing Record 41 of Set 2 | corinto
# Processing Record 42 of Set 2 | ocos
# Processing Record 43 of Set 2 | darbhanga
# Processing Record 44 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | seoul
# Processing Record 47 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 2 | san andres
# Processing Record 49 of Set 2 | la belgica
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | tura
# Processing Record 2 of Set 3 | tartus
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | vanimo
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | tanabe
# Processing Record 7 of Set 3 | aksarka
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | maple creek
# Processing Record 10 of Set 3 | sosva
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | san carlos de bariloche
# Processing Record 13 of Set 3 | havre-saint-pierre
# Processing Record 14 of Set 3 | santa cruz
# Processing Record 15 of Set 3 | necochea
# Processing Record 16 of Set 3 | kahului
# Processing Record 17 of Set 3 | tazovskiy
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | mao
# Processing Record 20 of Set 3 | tokur
# Processing Record 21 of Set 3 | pingliang
# Processing Record 22 of Set 3 | zarumilla
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | aksarayskiy
# Processing Record 25 of Set 3 | fallon
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | port lincoln
# Processing Record 28 of Set 3 | keti bandar
# Processing Record 29 of Set 3 | katherine
# Processing Record 30 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | wewak
# Processing Record 34 of Set 3 | abalak
# Processing Record 35 of Set 3 | teya
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | sibolga
# Processing Record 38 of Set 3 | grand gaube
# Processing Record 39 of Set 3 | qui nhon
# Processing Record 40 of Set 3 | ponta delgada
# Processing Record 41 of Set 3 | sayat
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | sistranda
# Processing Record 44 of Set 3 | russellville
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | alice springs
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | vestmanna
# Processing Record 49 of Set 3 | saint-michel-des-saints
# Processing Record 50 of Set 3 | port elizabeth
# Processing Record 1 of Set 4 | dodge city
# Processing Record 2 of Set 4 | bengkulu
# Processing Record 3 of Set 4 | jamestown
# Processing Record 4 of Set 4 | broome
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | raudeberg
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | pochutla
# Processing Record 9 of Set 4 | champerico
# Processing Record 10 of Set 4 | kalaleh
# Processing Record 11 of Set 4 | sechura
# Processing Record 12 of Set 4 | vilyuysk
# Processing Record 13 of Set 4 | scottsdale
# Processing Record 14 of Set 4 | dudinka
# Processing Record 15 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 16 of Set 4 | mapastepec
# Processing Record 17 of Set 4 | dorado
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | beckley
# Processing Record 20 of Set 4 | rio gallegos
# Processing Record 21 of Set 4 | sassandra
# Processing Record 22 of Set 4 | aykhal
# Processing Record 23 of Set 4 | ouesso
# Processing Record 24 of Set 4 | terrasini
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | chicama
# Processing Record 28 of Set 4 | pangnirtung
# Processing Record 29 of Set 4 | maykain
# City not found. Skipping...
# Processing Record 30 of Set 4 | castres
# Processing Record 31 of Set 4 | taywarah
# Processing Record 32 of Set 4 | coihaique
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | pozo colorado
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | port hardy
# Processing Record 40 of Set 4 | jerantut
# Processing Record 41 of Set 4 | biu
# Processing Record 42 of Set 4 | acajutla
# Processing Record 43 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 4 | berlevag
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | padang
# Processing Record 48 of Set 4 | coffs harbour
# Processing Record 49 of Set 4 | noumea
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | bereda
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | mitsamiouli
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | tres arroyos
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | vao
# Processing Record 9 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 10 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 11 of Set 5 | tatarsk
# Processing Record 12 of Set 5 | kenda
# Processing Record 13 of Set 5 | thunder bay
# Processing Record 14 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | bandarbeyla
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | kropotkin
# Processing Record 20 of Set 5 | marzuq
# Processing Record 21 of Set 5 | sola
# Processing Record 22 of Set 5 | bac lieu
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | kiunga
# Processing Record 25 of Set 5 | elko
# Processing Record 26 of Set 5 | tual
# Processing Record 27 of Set 5 | port augusta
# Processing Record 28 of Set 5 | xuddur
# Processing Record 29 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 30 of Set 5 | nizhneudinsk
# Processing Record 31 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 5 | ulaangom
# Processing Record 33 of Set 5 | toora-khem
# Processing Record 34 of Set 5 | avarua
# Processing Record 35 of Set 5 | burica
# City not found. Skipping...
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | port macquarie
# Processing Record 38 of Set 5 | santa maria
# Processing Record 39 of Set 5 | lata
# Processing Record 40 of Set 5 | nikolskoye
# Processing Record 41 of Set 5 | gat
# Processing Record 42 of Set 5 | dondo
# Processing Record 43 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 44 of Set 5 | iskateley
# Processing Record 45 of Set 5 | les cayes
# Processing Record 46 of Set 5 | tommot
# Processing Record 47 of Set 5 | aklera
# Processing Record 48 of Set 5 | saint anthony
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | lugovoy
# Processing Record 1 of Set 6 | atar
# Processing Record 2 of Set 6 | itarema
# Processing Record 3 of Set 6 | namatanai
# Processing Record 4 of Set 6 | pendleton
# Processing Record 5 of Set 6 | rocha
# Processing Record 6 of Set 6 | atherton
# Processing Record 7 of Set 6 | pandharpur
# Processing Record 8 of Set 6 | gambiran
# Processing Record 9 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 6 | potosi
# Processing Record 11 of Set 6 | rodrigues alves
# Processing Record 12 of Set 6 | hidalgo
# Processing Record 13 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | iquique
# Processing Record 16 of Set 6 | ambon
# Processing Record 17 of Set 6 | vertientes
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | capreol
# Processing Record 20 of Set 6 | nishihara
# Processing Record 21 of Set 6 | ojinaga
# Processing Record 22 of Set 6 | hamilton
# Processing Record 23 of Set 6 | axim
# Processing Record 24 of Set 6 | lorengau
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | chenzhou
# Processing Record 28 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 6 | henties bay
# Processing Record 30 of Set 6 | qaqortoq
# Processing Record 31 of Set 6 | havoysund
# Processing Record 32 of Set 6 | sale
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | cidreira
# Processing Record 35 of Set 6 | fortuna
# Processing Record 36 of Set 6 | tiksi
# Processing Record 37 of Set 6 | areka
# Processing Record 38 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 6 | lac du bonnet
# Processing Record 40 of Set 6 | hofn
# Processing Record 41 of Set 6 | nanakuli
# Processing Record 42 of Set 6 | kharakvasla
# Processing Record 43 of Set 6 | qingdao
# Processing Record 44 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 6 | lavrentiya
# Processing Record 46 of Set 6 | anadia
# Processing Record 47 of Set 6 | svetlyy
# Processing Record 48 of Set 6 | banda aceh
# Processing Record 49 of Set 6 | monte patria
# Processing Record 50 of Set 6 | salinopolis
# Processing Record 1 of Set 7 | evensk
# Processing Record 2 of Set 7 | esperance
# Processing Record 3 of Set 7 | jilotepec
# Processing Record 4 of Set 7 | ahipara
# Processing Record 5 of Set 7 | bondo
# Processing Record 6 of Set 7 | llanes
# Processing Record 7 of Set 7 | pangody
# Processing Record 8 of Set 7 | dikson
# Processing Record 9 of Set 7 | veraval
# Processing Record 10 of Set 7 | srednekolymsk
# Processing Record 11 of Set 7 | yingcheng
# Processing Record 12 of Set 7 | gao
# Processing Record 13 of Set 7 | cairns
# Processing Record 14 of Set 7 | takoradi
# Processing Record 15 of Set 7 | vanavara
# Processing Record 16 of Set 7 | mogadishu
# Processing Record 17 of Set 7 | temir
# Processing Record 18 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 7 | katobu
# Processing Record 20 of Set 7 | lundazi
# Processing Record 21 of Set 7 | sandpoint
# Processing Record 22 of Set 7 | nichlaul
# Processing Record 23 of Set 7 | kiyasovo
# Processing Record 24 of Set 7 | port blair
# Processing Record 25 of Set 7 | vila praia de ancora
# Processing Record 26 of Set 7 | rathdrum
# Processing Record 27 of Set 7 | vardo
# Processing Record 28 of Set 7 | aranos
# Processing Record 29 of Set 7 | aseri
# Processing Record 30 of Set 7 | boca del monte
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | palaikastron
# Processing Record 33 of Set 7 | asosa
# Processing Record 34 of Set 7 | atasu
# Processing Record 35 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 7 | amapa
# Processing Record 37 of Set 7 | darhan
# Processing Record 38 of Set 7 | sitka
# Processing Record 39 of Set 7 | saskylakh
# Processing Record 40 of Set 7 | omsukchan
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | north las vegas
# Processing Record 43 of Set 7 | muros
# Processing Record 44 of Set 7 | fortuna foothills
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | carnarvon
# Processing Record 47 of Set 7 | matara
# Processing Record 48 of Set 7 | luanda
# Processing Record 49 of Set 7 | nome
# Processing Record 50 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 8 | mehamn
# Processing Record 2 of Set 8 | ndele
# Processing Record 3 of Set 8 | khorixas
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | pacific grove
# Processing Record 6 of Set 8 | preeceville
# Processing Record 7 of Set 8 | maulvi bazar
# City not found. Skipping...
# Processing Record 8 of Set 8 | micheweni
# Processing Record 9 of Set 8 | solnechnyy
# Processing Record 10 of Set 8 | saint-pierre
# Processing Record 11 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 8 | kharp
# Processing Record 13 of Set 8 | asau
# Processing Record 14 of Set 8 | baruun-urt
# Processing Record 15 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 8 | lagoa
# Processing Record 17 of Set 8 | labuan
# Processing Record 18 of Set 8 | coquimbo
# Processing Record 19 of Set 8 | kampot
# Processing Record 20 of Set 8 | araouane
# Processing Record 21 of Set 8 | ha tinh
# Processing Record 22 of Set 8 | yushala
# Processing Record 23 of Set 8 | joshimath
# Processing Record 24 of Set 8 | husavik
# Processing Record 25 of Set 8 | warwick
# Processing Record 26 of Set 8 | amahai
# Processing Record 27 of Set 8 | bonthe
# Processing Record 28 of Set 8 | waingapu
# Processing Record 29 of Set 8 | hoquiam
# Processing Record 30 of Set 8 | aloleng
# Processing Record 31 of Set 8 | le vauclin
# Processing Record 32 of Set 8 | zyryanka
# Processing Record 33 of Set 8 | manggar
# Processing Record 34 of Set 8 | la rioja
# Processing Record 35 of Set 8 | gualeguay
# Processing Record 36 of Set 8 | choya
# Processing Record 37 of Set 8 | chabahar
# Processing Record 38 of Set 8 | labytnangi
# Processing Record 39 of Set 8 | tecoanapa
# Processing Record 40 of Set 8 | pakwach
# City not found. Skipping...
# Processing Record 41 of Set 8 | feltre
# Processing Record 42 of Set 8 | chokurdakh
# Processing Record 43 of Set 8 | maplewood
# Processing Record 44 of Set 8 | marsa matruh
# Processing Record 45 of Set 8 | xichang
# Processing Record 46 of Set 8 | manbij
# Processing Record 47 of Set 8 | villarrica
# Processing Record 48 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 49 of Set 8 | khani
# Processing Record 50 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 9 | makasar
# Processing Record 3 of Set 9 | ahuimanu
# Processing Record 4 of Set 9 | sigli
# Processing Record 5 of Set 9 | chuy
# Processing Record 6 of Set 9 | faya
# Processing Record 7 of Set 9 | beringovskiy
# Processing Record 8 of Set 9 | totoral
# Processing Record 9 of Set 9 | gidam
# Processing Record 10 of Set 9 | bilibino
# Processing Record 11 of Set 9 | fort nelson
# Processing Record 12 of Set 9 | meulaboh
# Processing Record 13 of Set 9 | amos
# Processing Record 14 of Set 9 | waipawa
# Processing Record 15 of Set 9 | bull savanna
# Processing Record 16 of Set 9 | geraldton
# Processing Record 17 of Set 9 | rincon
# Processing Record 18 of Set 9 | acapulco
# Processing Record 19 of Set 9 | lazaro cardenas
# Processing Record 20 of Set 9 | petrov val
# Processing Record 21 of Set 9 | pingyin
# Processing Record 22 of Set 9 | neuquen
# Processing Record 23 of Set 9 | kidal
# Processing Record 24 of Set 9 | kirkwall
# Processing Record 25 of Set 9 | kargil
# Processing Record 26 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 9 | flin flon
# Processing Record 29 of Set 9 | ucluelet
# Processing Record 30 of Set 9 | bougouni
# Processing Record 31 of Set 9 | bafra
# Processing Record 32 of Set 9 | sao felix do xingu
# Processing Record 33 of Set 9 | zabaykalsk
# Processing Record 34 of Set 9 | welkom
# Processing Record 35 of Set 9 | saint-augustin
# Processing Record 36 of Set 9 | japura
# Processing Record 37 of Set 9 | lufilufi
# Processing Record 38 of Set 9 | huilong
# Processing Record 39 of Set 9 | luderitz
# Processing Record 40 of Set 9 | kijang
# Processing Record 41 of Set 9 | huoqiu
# Processing Record 42 of Set 9 | taoudenni
# Processing Record 43 of Set 9 | olpad
# Processing Record 44 of Set 9 | agadez
# Processing Record 45 of Set 9 | oakdale
# Processing Record 46 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 9 | portland
# Processing Record 48 of Set 9 | yeppoon
# Processing Record 49 of Set 9 | ginda
# Processing Record 50 of Set 9 | aswan
# Processing Record 1 of Set 10 | fairbanks
# Processing Record 2 of Set 10 | saint-joseph
# Processing Record 3 of Set 10 | vila velha
# Processing Record 4 of Set 10 | sechelt
# Processing Record 5 of Set 10 | auce
# Processing Record 6 of Set 10 | yerbogachen
# Processing Record 7 of Set 10 | valdosta
# Processing Record 8 of Set 10 | nsanje
# Processing Record 9 of Set 10 | port hawkesbury
# Processing Record 10 of Set 10 | ikwiriri
# Processing Record 11 of Set 10 | hualmay
# Processing Record 12 of Set 10 | nayagarh
# Processing Record 13 of Set 10 | blois
# Processing Record 14 of Set 10 | hami
# Processing Record 15 of Set 10 | beira
# Processing Record 16 of Set 10 | kieta
# Processing Record 17 of Set 10 | lashio
# Processing Record 18 of Set 10 | grand-santi
# Processing Record 19 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 10 | tehachapi
# Processing Record 21 of Set 10 | hammerfest
# Processing Record 22 of Set 10 | faanui
# Processing Record 23 of Set 10 | tambacounda
# Processing Record 24 of Set 10 | leh
# Processing Record 25 of Set 10 | naze
# Processing Record 26 of Set 10 | koboldo
# City not found. Skipping...
# Processing Record 27 of Set 10 | yarada
# Processing Record 28 of Set 10 | muncar
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | san cristobal
# Processing Record 31 of Set 10 | arrecife
# Processing Record 32 of Set 10 | tarko-sale
# Processing Record 33 of Set 10 | rio tercero
# Processing Record 34 of Set 10 | altay
# Processing Record 35 of Set 10 | anloga
# Processing Record 36 of Set 10 | bangkalan
# Processing Record 37 of Set 10 | snezhnogorsk
# Processing Record 38 of Set 10 | isoka
# Processing Record 39 of Set 10 | kyren
# Processing Record 40 of Set 10 | bosaso
# Processing Record 41 of Set 10 | morvi
# Processing Record 42 of Set 10 | wuwei
# Processing Record 43 of Set 10 | rizhao
# Processing Record 44 of Set 10 | merzifon
# Processing Record 45 of Set 10 | harer
# Processing Record 46 of Set 10 | kandrian
# Processing Record 47 of Set 10 | kapustin yar
# Processing Record 48 of Set 10 | mosquera
# Processing Record 49 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 10 | talant
# Processing Record 1 of Set 11 | haines junction
# Processing Record 2 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 11 | isla aguada
# Processing Record 4 of Set 11 | tiznit
# Processing Record 5 of Set 11 | hvide sande
# Processing Record 6 of Set 11 | boguchany
# Processing Record 7 of Set 11 | ploemeur
# Processing Record 8 of Set 11 | san angelo
# Processing Record 9 of Set 11 | birin
# Processing Record 10 of Set 11 | mackenzie
# Processing Record 11 of Set 11 | baishishan
# Processing Record 12 of Set 11 | el wasta
# City not found. Skipping...
# Processing Record 13 of Set 11 | acurenam
# Processing Record 14 of Set 11 | rio grande
# Processing Record 15 of Set 11 | olafsvik
# Processing Record 16 of Set 11 | kautokeino
# Processing Record 17 of Set 11 | bundaberg
# Processing Record 18 of Set 11 | paita
# Processing Record 19 of Set 11 | somogyvar
# Processing Record 20 of Set 11 | los llanos de aridane
# Processing Record 21 of Set 11 | moose factory
# Processing Record 22 of Set 11 | marsaxlokk
# Processing Record 23 of Set 11 | gharo
# Processing Record 24 of Set 11 | prado
# Processing Record 25 of Set 11 | hanyang
# Processing Record 26 of Set 11 | abeokuta
# Processing Record 27 of Set 11 | kulhudhuffushi
# Processing Record 28 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 11 | mashhad
# Processing Record 30 of Set 11 | sosnogorsk
# Processing Record 31 of Set 11 | tanabi
# Processing Record 32 of Set 11 | simi
# Processing Record 33 of Set 11 | coahuayana
# Processing Record 34 of Set 11 | sabang
# Processing Record 35 of Set 11 | lasa
# Processing Record 36 of Set 11 | deputatskiy
# Processing Record 37 of Set 11 | iguape
# Processing Record 38 of Set 11 | raton
# Processing Record 39 of Set 11 | noyabrsk
# Processing Record 40 of Set 11 | kuytun
# Processing Record 41 of Set 11 | cabedelo
# Processing Record 42 of Set 11 | aripuana
# Processing Record 43 of Set 11 | rassvet
# Processing Record 44 of Set 11 | belfast
# Processing Record 45 of Set 11 | sur
# Processing Record 46 of Set 11 | umm lajj
# Processing Record 47 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 48 of Set 11 | sungai besar
# Processing Record 49 of Set 11 | svetlogorsk
# Processing Record 50 of Set 11 | ulverstone
# Processing Record 1 of Set 12 | yatou
# Processing Record 2 of Set 12 | ust-ilimsk
# Processing Record 3 of Set 12 | mastic beach
# Processing Record 4 of Set 12 | san martin
# Processing Record 5 of Set 12 | gushikawa
# Processing Record 6 of Set 12 | tiarei
# Processing Record 7 of Set 12 | sri aman
# Processing Record 8 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 12 | doctor juan manuel frutos
# Processing Record 10 of Set 12 | ixtapa
# Processing Record 11 of Set 12 | lebork
# Processing Record 12 of Set 12 | alugan
# Processing Record 13 of Set 12 | tamala
# Processing Record 14 of Set 12 | itoman
# Processing Record 15 of Set 12 | morlaix
# Processing Record 16 of Set 12 | irbil
# Processing Record 17 of Set 12 | gloversville
# Processing Record 18 of Set 12 | tuatapere
# Processing Record 19 of Set 12 | sambava
# Processing Record 20 of Set 12 | adrar
# Processing Record 21 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 22 of Set 12 | honavar
# Processing Record 23 of Set 12 | almaznyy
# Processing Record 24 of Set 12 | saquarema
# Processing Record 25 of Set 12 | beyneu
# Processing Record 26 of Set 12 | el alto
# Processing Record 27 of Set 12 | havelock
# Processing Record 28 of Set 12 | camabatela
# Processing Record 29 of Set 12 | pandan
# Processing Record 30 of Set 12 | russell
# Processing Record 31 of Set 12 | kasongo-lunda
# Processing Record 32 of Set 12 | mangaratiba
# Processing Record 33 of Set 12 | plettenberg bay
# Processing Record 34 of Set 12 | ukiah
# Processing Record 35 of Set 12 | port-gentil
# Processing Record 36 of Set 12 | praia da vitoria
# Processing Record 37 of Set 12 | karasjok
# Processing Record 38 of Set 12 | puro
# Processing Record 39 of Set 12 | peleduy
# Processing Record 40 of Set 12 | honiara
# Processing Record 41 of Set 12 | trairi
# Processing Record 42 of Set 12 | agva
# City not found. Skipping...
# Processing Record 43 of Set 12 | te anau
# Processing Record 44 of Set 12 | progreso
# Processing Record 45 of Set 12 | vestmannaeyjar
# Processing Record 46 of Set 12 | guhagar
# Processing Record 47 of Set 12 | tevaitoa
# Processing Record 48 of Set 12 | dicabisagan
# Processing Record 49 of Set 12 | pedernales
# Processing Record 50 of Set 12 | middlebury
# Processing Record 1 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 2 of Set 13 | tera
# Processing Record 3 of Set 13 | puerto carreno
# Processing Record 4 of Set 13 | hovd
# Processing Record 5 of Set 13 | divnomorskoye
# Processing Record 6 of Set 13 | nizhneangarsk
# Processing Record 7 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 13 | shebunino
# Processing Record 9 of Set 13 | opuwo
# Processing Record 10 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 11 of Set 13 | ayan
# Processing Record 12 of Set 13 | guanaja
# Processing Record 13 of Set 13 | nanortalik
# Processing Record 14 of Set 13 | ust-ordynskiy
# Processing Record 15 of Set 13 | santa cruz del sur
# Processing Record 16 of Set 13 | mount gambier
# Processing Record 17 of Set 13 | osakarovka
# Processing Record 18 of Set 13 | masuguru
# Processing Record 19 of Set 13 | pafos
# Processing Record 20 of Set 13 | sanary-sur-mer
# Processing Record 21 of Set 13 | mnogovershinnyy
# Processing Record 22 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 13 | prince albert
# Processing Record 24 of Set 13 | bud
# Processing Record 25 of Set 13 | talnakh
# Processing Record 26 of Set 13 | keflavik
# Processing Record 27 of Set 13 | qurayyat
# Processing Record 28 of Set 13 | peniche
# Processing Record 29 of Set 13 | riviere-au-renard
# Processing Record 30 of Set 13 | terrace bay
# Processing Record 31 of Set 13 | hervey bay
# Processing Record 32 of Set 13 | touros
# Processing Record 33 of Set 13 | gazojak
# Processing Record 34 of Set 13 | makokou
# Processing Record 35 of Set 13 | abu samrah
# Processing Record 36 of Set 13 | qasigiannguit
# Processing Record 37 of Set 13 | takaka
# Processing Record 38 of Set 13 | split
# Processing Record 39 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 40 of Set 13 | nizhnyaya tavda
# Processing Record 41 of Set 13 | poum
# Processing Record 42 of Set 13 | cherepovets
# Processing Record 43 of Set 13 | papenburg
# Processing Record 44 of Set 13 | chumikan
# Processing Record 45 of Set 13 | superior
# Processing Record 46 of Set 13 | roblin
# Processing Record 47 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 48 of Set 13 | riyadh
# Processing Record 49 of Set 13 | escanaba
# Processing Record 50 of Set 13 | merke
# Processing Record 1 of Set 14 | mananjary
# Processing Record 2 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 14 | kununurra
# Processing Record 4 of Set 14 | zonguldak
# Processing Record 5 of Set 14 | san jeronimo
# Processing Record 6 of Set 14 | cahir
# Processing Record 7 of Set 14 | ikom
# Processing Record 8 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 14 | demba
# Processing Record 10 of Set 14 | vuktyl
# Processing Record 11 of Set 14 | saint-georges
# Processing Record 12 of Set 14 | calvia
# Processing Record 13 of Set 14 | waw
# Processing Record 14 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 14 | medea
# Processing Record 16 of Set 14 | mikhaylovka
# Processing Record 17 of Set 14 | lima
# Processing Record 18 of Set 14 | rosetta
# Processing Record 19 of Set 14 | nemuro
# Processing Record 20 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 21 of Set 14 | labuhan
# Processing Record 22 of Set 14 | manaus
# Processing Record 23 of Set 14 | nisia floresta
# Processing Record 24 of Set 14 | pervomaysk
# Processing Record 25 of Set 14 | kampong chhnang
# Processing Record 26 of Set 14 | makat
# Processing Record 27 of Set 14 | roald
# Processing Record 28 of Set 14 | carauari
# Processing Record 29 of Set 14 | aitape
# Processing Record 30 of Set 14 | ypsonas
# Processing Record 31 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 32 of Set 14 | poshekhonye
# Processing Record 33 of Set 14 | lusambo
# Processing Record 34 of Set 14 | belyy yar
# Processing Record 35 of Set 14 | yagodnoye
# Processing Record 36 of Set 14 | manaure
# Processing Record 37 of Set 14 | basco
# Processing Record 38 of Set 14 | sioux lookout
# Processing Record 39 of Set 14 | coos bay
# Processing Record 40 of Set 14 | dongsheng
# Processing Record 41 of Set 14 | kursenai
# Processing Record 42 of Set 14 | abha
# Processing Record 43 of Set 14 | otane
# Processing Record 44 of Set 14 | poddorye
# Processing Record 45 of Set 14 | maridi
# Processing Record 46 of Set 14 | bontang
# Processing Record 47 of Set 14 | jian
# Processing Record 48 of Set 14 | basoko
# Processing Record 49 of Set 14 | kajaani
# Processing Record 50 of Set 14 | lobva
# Processing Record 1 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 15 | mamit
# Processing Record 3 of Set 15 | tarkwa
# Processing Record 4 of Set 15 | clyde river
# Processing Record 5 of Set 15 | kudahuvadhoo
# Processing Record 6 of Set 15 | yar-sale
# Processing Record 7 of Set 15 | inuvik
# Processing Record 8 of Set 15 | palmas
# Processing Record 9 of Set 15 | tokoroa
# Processing Record 10 of Set 15 | rokytne
# Processing Record 11 of Set 15 | lincoln
# Processing Record 12 of Set 15 | turukhansk
# Processing Record 13 of Set 15 | palauig
# Processing Record 14 of Set 15 | churapcha
# Processing Record 15 of Set 15 | quelimane
# Processing Record 16 of Set 15 | nogliki
# Processing Record 17 of Set 15 | hambantota
# Processing Record 18 of Set 15 | kerman
# Processing Record 19 of Set 15 | pinega
# Processing Record 20 of Set 15 | marsh harbour
# Processing Record 21 of Set 15 | porbandar
# Processing Record 22 of Set 15 | biak
# Processing Record 23 of Set 15 | ati
# Processing Record 24 of Set 15 | assiniboia
# Processing Record 25 of Set 15 | pahrump
# Processing Record 26 of Set 15 | bouar
# Processing Record 27 of Set 15 | tambura
# Processing Record 28 of Set 15 | jaguaruna
# Processing Record 29 of Set 15 | kaeo
# Processing Record 30 of Set 15 | beroroha
# Processing Record 31 of Set 15 | goya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 666

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Penasco  31.3167 -113.5333     55.90        57          91
# 1         Qaanaaq  77.4840  -69.3632     -3.28        59           7
# 2          Muriae -21.1306  -42.3664     85.71        68          93
# 3    Punta Arenas -53.1500  -70.9167     64.11        42          72
# 4           Buala  -8.1450  159.5921     78.78        81          79
# 5         Rikitea -23.1203 -134.9692     78.55        74          57
# 6  Cabo San Lucas  22.8909 -109.9124     74.61        64          93
# 7         Mataura -46.1927  168.8643     48.81        97           0
# 8           Moron -34.6534  -58.6198     91.96        63           0
# 9            Lebu -37.6167  -73.6500     65.28        61           0
#
#    Wind Speed Current Description Country                 Date
# 0        8.99              Clouds      MX  2023-01-28 18:00:06
# 1        9.04               Clear      GL  2023-01-28 18:00:10
# 2        1.10              Clouds      BR  2023-01-28 18:00:12
# 3       21.27              Clouds      CL  2023-01-28 18:00:12
# 4        1.19                Rain      SB  2023-01-28 18:00:14
# 5       11.48              Clouds      PF  2023-01-28 18:00:16
# 6        6.40              Clouds      MX  2023-01-28 17:59:39
# 7        1.30               Clear      NZ  2023-01-28 18:00:16
# 8        3.83               Clear      AR  2023-01-28 17:59:22
# 9       21.36               Clear      CL  2023-01-28 17:57:03

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=new_order)

# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Penasco      MX  31.3167 -113.5333     55.90        57          91
# 1         Qaanaaq      GL  77.4840  -69.3632     -3.28        59           7
# 2          Muriae      BR -21.1306  -42.3664     85.71        68          93
# 3    Punta Arenas      CL -53.1500  -70.9167     64.11        42          72
# 4           Buala      SB  -8.1450  159.5921     78.78        81          79
#
#    Wind Speed Current Description
# 0        8.99              Clouds
# 1        9.04               Clear
# 2        1.10              Clouds
# 3       21.27              Clouds
# 4        1.19                Rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
csv_file_name = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(csv_file_name)
